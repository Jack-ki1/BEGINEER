# %% [markdown]
# <div style="background-color:lightgreen; padding:40px; text-align:center; border-radius:10px;">
#
#   <h1 style="color:#333; font-size:3em; margin-bottom:20px;">A LOOK INTO PANDAS FROM A-Z </h1>
#
#   <p style="font-size:1.5em; color:#666;">Diving deep python pandas library</p>
#
# </div>

# %%
import pandas as pd
import numpy as np

# %% [raw]
# df.to_numpy() df.to_dict() df.to_csv() df.to_excel() df.to_json()
# df.to_html() df.to_markdown() df.to_sql() df.to_clipboard() df.to_records() df.to_string() df.to_stata()
# df.to_feather() df.to_parquet() df.to_hdf() df.to_latex() df.to_gbq() df.to_pickle()

# %%
df=pd.read_csv("S002_DATA.csv", nrows=50)

# %% [markdown]
# ## how to remove the output (optional)
# ### PRINT- Prints the values
# ### DISPLAY -gives a more appealing output than print

# %%
df2=df.copy()

# %%
df.head()
# Out:
#    Customer_ID     Name  Age  Gender  Country Date_of_Purchase  \
# 0            1  Charlie   51    Male       UK       2022-09-09
# 1            2  Charlie   62    Male   Canada       2022-01-30
# 2            3    David   42    Male   Canada       2022-04-21
# 3            4      Eve   67  Female       UK       2022-10-07
# 4            5      Eve   65  Female  Germany       2022-06-15
#
#   Product_Category  Product_ID  Quantity  Price_per_Unit  Total_Spent  \
# 0            Books        1938         4           92.09       368.36
# 1            Books        1890         6           98.92       593.52
# 2            Books        1607         9           31.37       282.33
# 3      Electronics        1424         5           68.12       340.60
# 4         Clothing        1119         9           99.15       892.35
#
#    Discount_Applied Payment_Method Customer_Feedback Membership_Status
# 0             False  Bank Transfer           Neutral               NaN
# ...

# %%
df.tail()
# Out:
#     Customer_ID     Name  Age  Gender Country Date_of_Purchase  \
# 95           96      Eve   51  Female     USA       2022-10-25
# 96           97  Charlie   38    Male  France       2022-01-14
# 97           98    David   37  Female  Canada       2022-11-23
# 98           99      Bob   67    Male  Canada       2022-11-27
# 99          100      Bob   23    Male  France       2022-01-10
#
#    Product_Category  Product_ID  Quantity  Price_per_Unit  Total_Spent  \
# 95        Groceries        1553         4           68.99       275.96
# 96      Electronics        1542         2           15.79        31.58
# 97        Groceries        1122         3           69.50       208.50
# 98      Electronics        1976         5           81.64       408.20
# 99            Books        1055         2           53.57       107.14
#
#     Discount_Applied Payment_Method Customer_Feedback Membership_Status
# 95             False           Cash          Positive               NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Customer_ID        50 non-null     int64
#  1   Name               50 non-null     object
#  2   Age                50 non-null     int64
#  3   Gender             50 non-null     object
#  4   Country            50 non-null     object
#  5   Date_of_Purchase   50 non-null     object
#  6   Product_Category   50 non-null     object
#  7   Product_ID         50 non-null     int64
#  8   Quantity           50 non-null     int64
#  9   Price_per_Unit     50 non-null     float64
#  10  Total_Spent        50 non-null     float64
#  11  Discount_Applied   50 non-null     bool
#  12  Payment_Method     50 non-null     object
#  13  Customer_Feedback  50 non-null     object
#  14  Membership_Status  42 non-null     object
# dtypes: bool(1), float64(2), int64(4), object(8)
# ...

# %%
df.describe()
# Out:
#        Customer_ID        Age   Product_ID   Quantity  Price_per_Unit  \
# count     50.00000  50.000000    50.000000  50.000000       50.000000
# mean      25.50000  44.460000  1482.580000   4.920000       50.268200
# std       14.57738  15.563183   274.093615   2.406115       30.526194
# min        1.00000  18.000000  1046.000000   1.000000        5.400000
# 25%       13.25000  31.250000  1265.250000   3.000000       22.095000
# 50%       25.50000  45.000000  1435.000000   5.000000       49.740000
# 75%       37.75000  59.250000  1726.250000   7.000000       74.010000
# max       50.00000  69.000000  1938.000000   9.000000       99.770000
#
#        Total_Spent
# count    50.000000
# mean    231.897000
# std     192.826681
# min      11.000000
# 25%      82.865000
# 50%     180.285000
# 75%     297.855000
# max     892.350000

# %%
 df.columns
# Out:
# Index(['Customer_ID', 'Name', 'Age', 'Gender', 'Country', 'Date_of_Purchase',
#        'Product_Category', 'Product_ID', 'Quantity', 'Price_per_Unit',
#        'Total_Spent', 'Discount_Applied', 'Payment_Method',
#        'Customer_Feedback', 'Membership_Status'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
 df.dtypes
# Out:
# Customer_ID            int64
# Name                  object
# Age                    int64
# Gender                object
# Country               object
# Date_of_Purchase      object
# Product_Category      object
# Product_ID             int64
# Quantity               int64
# Price_per_Unit       float64
# Total_Spent          float64
# Discount_Applied        bool
# Payment_Method        object
# Customer_Feedback     object
# Membership_Status     object
# dtype: object

# %%
 df.shape
# Out:
# (50, 15)

# %%
df.size
# Out:
# 750

# %%
df.values
# Out:
# array([[1, 'Charlie', 51, 'Male', 'UK', '2022-09-09', 'Books', 1938, 4,
#         92.09, 368.36, False, 'Bank Transfer', 'Neutral', nan],
#        [2, 'Charlie', 62, 'Male', 'Canada', '2022-01-30', 'Books', 1890,
#         6, 98.92, 593.52, True, 'PayPal', 'Negative', 'Gold'],
#        [3, 'David', 42, 'Male', 'Canada', '2022-04-21', 'Books', 1607, 9,
#         31.37, 282.33, False, 'Credit Card', 'Positive', 'Bronze'],
#        [4, 'Eve', 67, 'Female', 'UK', '2022-10-07', 'Electronics', 1424,
#         5, 68.12, 340.6, False, 'Cash', 'Positive', 'Silver'],
#        [5, 'Eve', 65, 'Female', 'Germany', '2022-06-15', 'Clothing',
#         1119, 9, 99.15, 892.35, False, 'Cash', 'Positive', 'Bronze'],
#        [6, 'Charlie', 68, 'Female', 'France', '2022-10-14',
#         'Electronics', 1345, 3, 93.93, 281.79, False, 'Credit Card',
#         'Positive', 'Bronze'],
#        [7, 'David', 18, 'Male', 'France', '2022-05-07', 'Books', 1802, 1,
# ...

# %%
df.duplicated()
display(df.duplicated().sum())
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Name, Age, Gender, Country, Date_of_Purchase, Product_Category, Product_ID, Quantity, Price_per_Unit, Total_Spent, Discount_Applied, Payment_Method, Customer_Feedback, Membership_Status]
# Index: []

# %%
df.drop_duplicates(inplace=True)

# %%
#df.style.highlight_null(color='yellow')

# %%
df.isna()
df.isna().sum()
# Out:
# Customer_ID          0
# Name                 0
# Age                  0
# Gender               0
# Country              0
# Date_of_Purchase     0
# Product_Category     0
# Product_ID           0
# Quantity             0
# Price_per_Unit       0
# Total_Spent          0
# Discount_Applied     0
# Payment_Method       0
# Customer_Feedback    0
# Membership_Status    8
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#     Customer_ID     Name  Age  Gender  Country Date_of_Purchase  \
# 0             1  Charlie   51    Male       UK       2022-09-09
# 19           20    David   69  Female  Germany       2022-10-31
# 21           22      Eve   38  Female       UK       2022-12-05
# 22           23      Eve   61    Male  Germany       2022-01-25
# 30           31    Alice   64  Female       UK       2022-01-14
# 31           32      Eve   44    Male      USA       2022-11-24
# 40           41    David   25  Female   France       2022-09-12
# 42           43      Bob   68    Male  Germany       2022-06-28
# 50           51      Eve   64  Female       UK       2022-08-12
# 53           54      Eve   60  Female      USA       2022-11-15
# 78           79      Bob   34  Female      USA       2022-01-18
# 88           89  Charlie   42    Male   Canada       2022-08-18
# 90           91    David   45    Male   Canada       2022-04-30
# 95           96      Eve   51  Female      USA       2022-10-25
# ...

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (84, 15)

# %%
df2.sort_values(['Country', 'Name'], ascending=[False,True])[:5]
# Out:
#     Customer_ID     Name  Age Gender Country Date_of_Purchase  \
# 26           27    Alice   36   Male     USA       2022-04-01
# 16           17  Charlie   30   Male     USA       2022-08-07
# 36           37  Charlie   28   Male     USA       2022-06-30
# 44           45  Charlie   43   Male     USA       2022-08-08
# 7             8    David   60   Male     USA       2022-10-02
#
#    Product_Category  Product_ID  Quantity  Price_per_Unit  Total_Spent  \
# 26      Electronics        1287         8            5.40        43.20
# 16        Groceries        1640         4           40.21       160.84
# 36         Clothing        1464         5           39.23       196.15
# 44         Clothing        1659         2           85.98       171.96
# 7             Books        1931         2           19.65        39.30
#
#     Discount_Applied Payment_Method Customer_Feedback Membership_Status
# 26              True    Credit Card          Negative              Gold
# ...

# %%
df2.sort_values(by='Date_of_Purchase', ascending=False, na_position='first')#na_position- stands for the null values
# Out:
#     Customer_ID     Name  Age  Gender  Country Date_of_Purchase  \
# 35           36      Bob   39    Male  Germany       2022-12-27
# 25           26    Alice   39  Female  Germany       2022-12-11
# 29           30    David   24    Male   France       2022-12-10
# 12           13      Bob   69  Female       UK       2022-12-09
# 21           22      Eve   38  Female       UK       2022-12-05
# 37           38      Bob   19    Male   Canada       2022-12-01
# 39           40    David   28  Female   Canada       2022-11-28
# 31           32      Eve   44    Male      USA       2022-11-24
# 19           20    David   69  Female  Germany       2022-10-31
# 49           50    David   24    Male      USA       2022-10-25
# 32           33      Eve   36  Female       UK       2022-10-24
# 33           34  Charlie   50  Female       UK       2022-10-21
# 23           24      Bob   55  Female  Germany       2022-10-20
# 5             6  Charlie   68  Female   France       2022-10-14
# ...

# %%
df2.sort_index(ascending=False)[:5]
# Out:
#     Customer_ID   Name  Age  Gender Country Date_of_Purchase Product_Category  \
# 49           50  David   24    Male     USA       2022-10-25        Furniture
# 48           49    Bob   46  Female  France       2022-03-13      Electronics
# 47           48  David   50    Male  France       2022-05-25         Clothing
# 46           47  Alice   46  Female      UK       2022-07-01        Groceries
# 45           46    Bob   65    Male  Canada       2022-02-17        Groceries
#
#     Product_ID  Quantity  Price_per_Unit  Total_Spent  Discount_Applied  \
# 49        1367         2           41.36        82.72             False
# 48        1446         9            7.03        63.27              True
# 47        1122         5           81.13       405.65              True
# 46        1673         3           73.26       219.78              True
# 45        1883         4           28.92       115.68              True
#
#    Payment_Method Customer_Feedback Membership_Status
# ...

# %%
df2.reset_index(drop=True)[:4]
# Out:
#    Customer_ID     Name  Age  Gender Country Date_of_Purchase  \
# 0            1  Charlie   51    Male      UK       2022-09-09
# 1            2  Charlie   62    Male  Canada       2022-01-30
# 2            3    David   42    Male  Canada       2022-04-21
# 3            4      Eve   67  Female      UK       2022-10-07
#
#   Product_Category  Product_ID  Quantity  Price_per_Unit  Total_Spent  \
# 0            Books        1938         4           92.09       368.36
# 1            Books        1890         6           98.92       593.52
# 2            Books        1607         9           31.37       282.33
# 3      Electronics        1424         5           68.12       340.60
#
#    Discount_Applied Payment_Method Customer_Feedback Membership_Status
# 0             False  Bank Transfer           Neutral               NaN
# 1              True         PayPal          Negative              Gold
# 2             False    Credit Card          Positive            Bronze
# ...

# %%
df2.set_index(['Product_Category','Product_ID'])[:4]#you may add inplace=True if  you want the change to be fully applied to the whole  dataset
# Out:
#                              Customer_ID     Name  Age  Gender Country  \
# Product_Category Product_ID
# Books            1938                  1  Charlie   51    Male      UK
#                  1890                  2  Charlie   62    Male  Canada
#                  1607                  3    David   42    Male  Canada
# Electronics      1424                  4      Eve   67  Female      UK
#
#                             Date_of_Purchase  Quantity  Price_per_Unit  \
# Product_Category Product_ID
# Books            1938             2022-09-09         4           92.09
#                  1890             2022-01-30         6           98.92
#                  1607             2022-04-21         9           31.37
# Electronics      1424             2022-10-07         5           68.12
#
#                              Total_Spent  Discount_Applied Payment_Method  \
# Product_Category Product_ID
# Books            1938             368.36             False  Bank Transfer
# ...

# %%
df2.rename(columns={'Country': 'Nation'}, inplace=True)
df2.head(3)
# Out:
#    Customer_ID     Name  Age Gender  Nation Date_of_Purchase Product_Category  \
# 0            1  Charlie   51   Male      UK       2022-09-09            Books
# 1            2  Charlie   62   Male  Canada       2022-01-30            Books
# 2            3    David   42   Male  Canada       2022-04-21            Books
#
#    Product_ID  Quantity  Price_per_Unit  Total_Spent  Discount_Applied  \
# 0        1938         4           92.09       368.36             False
# 1        1890         6           98.92       593.52              True
# 2        1607         9           31.37       282.33             False
#
#   Payment_Method Customer_Feedback Membership_Status
# 0  Bank Transfer           Neutral               NaN
# 1         PayPal          Negative              Gold
# 2    Credit Card          Positive            Bronze

# %%
Q= df2.rename_axis(None, axis=1)
Q.head(5)
# Out:
#    Customer_ID     Name  Age  Gender   Nation Date_of_Purchase  \
# 0            1  Charlie   51    Male       UK       2022-09-09
# 1            2  Charlie   62    Male   Canada       2022-01-30
# 2            3    David   42    Male   Canada       2022-04-21
# 3            4      Eve   67  Female       UK       2022-10-07
# 4            5      Eve   65  Female  Germany       2022-06-15
#
#   Product_Category  Product_ID  Quantity  Price_per_Unit  Total_Spent  \
# 0            Books        1938         4           92.09       368.36
# 1            Books        1890         6           98.92       593.52
# 2            Books        1607         9           31.37       282.33
# 3      Electronics        1424         5           68.12       340.60
# 4         Clothing        1119         9           99.15       892.35
#
#    Discount_Applied Payment_Method Customer_Feedback Membership_Status
# 0             False  Bank Transfer           Neutral               NaN
# ...

# %%
W=df['Customer_ID'].astype('float')
W[:5]
# Out:
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    6.0
# Name: Customer_ID, dtype: float64

# %%
df2.map(lambda x: len(str(x)))[:4]
# Out:
#    Customer_ID  Name  Age  Gender  Nation  Date_of_Purchase  Product_Category  \
# 0            1     7    2       4       2                10                 5
# 1            1     7    2       4       6                10                 5
# 2            1     5    2       4       6                10                 5
# 3            1     3    2       6       2                10                11
#
#    Product_ID  Quantity  Price_per_Unit  Total_Spent  Discount_Applied  \
# 0           4         1               5            6                 5
# 1           4         1               5            6                 4
# 2           4         1               5            6                 5
# 3           4         1               5            5                 5
#
#    Payment_Method  Customer_Feedback  Membership_Status
# 0              13                  7                  3
# 1               6                  8                  4
# ...

# %%
 m = df2['Age'] % 3 == 0
df2['Age'].where(m, df2['Age'])[:5]
# Out:
# 0    51
# 1    62
# 2    42
# 3    67
# 4    65
# Name: Age, dtype: int64

# %%
df2['Age'].where(m, -df2['Age']) == df2['Age'].mask(~m, -df2['Age'])
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 95    True
# 96    True
# 97    True
# 98    True
# 99    True
# Name: Age, Length: 100, dtype: bool

# %%
df.query("Country == 'USA'").sort_values(by='Total_Spent', ascending=False)[:10]
# Out:
#     Customer_ID     Name  Age  Gender Country Date_of_Purchase  \
# 52           53  Charlie   26  Female     USA       2022-10-15
# 86           87    David   61  Female     USA       2022-10-07
# 73           74      Eve   43    Male     USA       2022-05-03
# 70           71    Alice   42    Male     USA       2022-08-17
# 36           37  Charlie   28    Male     USA       2022-06-30
# 44           45  Charlie   43    Male     USA       2022-08-08
# 16           17  Charlie   30    Male     USA       2022-08-07
# 72           73      Eve   42  Female     USA       2022-07-30
# 84           85  Charlie   22    Male     USA       2022-08-08
# 71           72      Eve   28  Female     USA       2022-06-02
#
#    Product_Category  Product_ID  Quantity  Price_per_Unit  Total_Spent  \
# 52            Books        1136         8           62.41       499.28
# 86        Furniture        1289         5           84.10       420.50
# ...

# %%
E=df2.eval('NEW_COL1 = Customer_ID % Age')
E[:5]
# Out:
#    Customer_ID     Name  Age  Gender   Nation Date_of_Purchase  \
# 0            1  Charlie   51    Male       UK       2022-09-09
# 1            2  Charlie   62    Male   Canada       2022-01-30
# 2            3    David   42    Male   Canada       2022-04-21
# 3            4      Eve   67  Female       UK       2022-10-07
# 4            5      Eve   65  Female  Germany       2022-06-15
#
#   Product_Category  Product_ID  Quantity  Price_per_Unit  Total_Spent  \
# 0            Books        1938         4           92.09       368.36
# 1            Books        1890         6           98.92       593.52
# 2            Books        1607         9           31.37       282.33
# 3      Electronics        1424         5           68.12       340.60
# 4         Clothing        1119         9           99.15       892.35
#
#    Discount_Applied Payment_Method Customer_Feedback Membership_Status  \
# 0             False  Bank Transfer           Neutral               NaN
# ...

# %%
pick_row=next(df.iterrows())[1]
pick_row
# Out:
# Customer_ID                   2
# Name                    Charlie
# Age                          62
# Gender                     Male
# Country                  Canada
# Date_of_Purchase     2022-01-30
# Product_Category          Books
# Product_ID                 1890
# Quantity                      6
# Price_per_Unit            98.92
# Total_Spent              593.52
# Discount_Applied           True
# Payment_Method           PayPal
# Customer_Feedback      Negative
# Membership_Status          Gold
# Name: 1, dtype: object

# %%
df.select_dtypes(include=['object'], exclude=['int64','float64'])#parameters are include or exclude
# Out:
#        Name  Gender  Country Date_of_Purchase Product_Category Payment_Method  \
# 1   Charlie    Male   Canada       2022-01-30            Books         PayPal
# 2     David    Male   Canada       2022-04-21            Books    Credit Card
# 3       Eve  Female       UK       2022-10-07      Electronics           Cash
# 4       Eve  Female  Germany       2022-06-15         Clothing           Cash
# 5   Charlie  Female   France       2022-10-14      Electronics    Credit Card
# ..      ...     ...      ...              ...              ...            ...
# 92    David  Female   Canada       2022-05-27            Books           Cash
# 93    David    Male   Canada       2022-11-12            Books         PayPal
# 94      Eve  Female   France       2022-10-17        Furniture    Credit Card
# 96  Charlie    Male   France       2022-01-14      Electronics  Bank Transfer
# 98      Bob    Male   Canada       2022-11-27      Electronics         PayPal
#
# ...

# %%
df2.sample(n=3, random_state=1, axis='columns')
# Out:
#     Gender  Product_ID Product_Category
# 0     Male        1938            Books
# 1     Male        1890            Books
# 2     Male        1607            Books
# 3   Female        1424      Electronics
# 4   Female        1119         Clothing
# ..     ...         ...              ...
# 95  Female        1553        Groceries
# 96    Male        1542      Electronics
# 97  Female        1122        Groceries
# 98    Male        1976      Electronics
# 99    Male        1055            Books
#
# [100 rows x 3 columns]

# %%
df['Product_Category'].unique()
# Out:
# array(['Books', 'Electronics', 'Clothing', 'Furniture', 'Groceries'],
#       dtype=object)

# %%
df['Product_Category'].nunique()
# Out:
# 5

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      43
# Female    41
# Name: count, dtype: int64

# %%
df['Total_Spent'].count()
# Out:
# 84

# %%
df['Total_Spent'].mean().round(1)
# Out:
# 239.1

# %%
df['Total_Spent'].median()
# Out:
# 180.99

# %%
df['Total_Spent'].mode()
# Out:
# 0      11.00
# 1      28.56
# 2      31.35
# 3      31.58
# 4      33.30
#        ...
# 79    593.52
# 80    698.39
# 81    836.55
# 82    892.35
# 83    894.60
# Name: Total_Spent, Length: 84, dtype: float64

# %%
df['Total_Spent'].agg(['count','mean','median','min','max', 'sum','std', 'var'])
# Out:
# count        84.000000
# mean        239.137500
# median      180.990000
# min          11.000000
# max         894.600000
# sum       20087.550000
# std         206.052093
# var       42457.465074
# Name: Total_Spent, dtype: float64

# %%
df['Total_Spent'].std()
# Out:
# 206.05209310850884

# %%
df['Total_Spent'].var()
# Out:
# 42457.4650743976

# %%
df['Total_Spent'].min()
# Out:
# 11.0

# %%
df['Total_Spent'].max()
# Out:
# 894.6

# %%
df['Total_Spent'].sum()
# Out:
# 20087.550000000007

# %%
df['Total_Spent'].cumsum()
# Out:
# 1       593.52
# 2       875.85
# 3      1216.45
# 4      2108.80
# 5      2390.59
#         ...
# 92    19235.55
# 93    19301.45
# 94    19647.77
# 96    19679.35
# 98    20087.55
# Name: Total_Spent, Length: 84, dtype: float64

# %%
df['Customer_ID'].cumprod()
# Out:
# 1       2
# 2       6
# 3      24
# 4     120
# 5     720
#      ...
# 92      0
# 93      0
# 94      0
# 96      0
# 98      0
# Name: Customer_ID, Length: 84, dtype: int64

# %%
df['Customer_ID'].diff()
# Out:
# 1     NaN
# 2     1.0
# 3     1.0
# 4     1.0
# 5     1.0
#      ...
# 92    1.0
# 93    1.0
# 94    1.0
# 96    2.0
# 98    2.0
# Name: Customer_ID, Length: 84, dtype: float64

# %%
df['Total_Spent'].pct_change()
# Out:
# 1           NaN
# 2     -0.524313
# 3      0.206390
# 4      1.619935
# 5     -0.684216
#         ...
# 92    -0.303762
# 93    -0.828072
# 94     4.255235
# 96    -0.908813
# 98    11.925902
# Name: Total_Spent, Length: 84, dtype: float64

# %%
df['Total_Spent'].corr(df['Price_per_Unit']).round(2)
# Out:
# 0.65

# %%
df['Total_Spent'].cov(df['Price_per_Unit']).round(2)
# Out:
# 3888.5

# %%
default_rank = df['Total_Spent'].rank(ascending=False)
default_rank
# Out:
# 1      5.0
# 2     25.0
# 3     22.0
# 4      2.0
# 5     26.0
#       ...
# 92    19.0
# 93    68.0
# 94    21.0
# 96    81.0
# 98    16.0
# Name: Total_Spent, Length: 84, dtype: float64

# %%
pct_rank = df['Total_Spent'].rank(pct=True)
display(pct_rank)
# Out:
# 1     0.952381
# 2     0.714286
# 3     0.750000
# 4     0.988095
# 5     0.702381
#         ...
# 92    0.785714
# 93    0.202381
# 94    0.761905
# 96    0.047619
# 98    0.821429
# Name: Total_Spent, Length: 84, dtype: float64

# %%
df['Total_Spent'].clip(700, 900).sort_values(ascending=False)
# Out:
# 85    894.60
# 4     892.35
# 87    836.55
# 62    700.00
# 70    700.00
#        ...
# 33    700.00
# 32    700.00
# 29    700.00
# 28    700.00
# 98    700.00
# Name: Total_Spent, Length: 84, dtype: float64

# %%
df['Total_Spent'].abs()
# Out:
# 1     593.52
# 2     282.33
# 3     340.60
# 4     892.35
# 5     281.79
#        ...
# 92    383.30
# 93     65.90
# 94    346.32
# 96     31.58
# 98    408.20
# Name: Total_Spent, Length: 84, dtype: float64

# %% [raw]
# df.prod?

# %%
df['Total_Spent'].skew().round(3)
# Out:
# 1.366

# %%
df['Total_Spent'].kurt().round(3)
# Out:
# 1.584

# %%
df['Total_Spent'].quantile()
# Out:
# 180.99

# %%
df['Total_Spent'].idxmin()
# Out:
# 13

# %%
df['Total_Spent'].idxmax()
# Out:
# 85

# %%
df['Total_Spent'].nlargest(1)
# Out:
# 85    894.6
# Name: Total_Spent, dtype: float64

# %%
df['Total_Spent'].nsmallest(1)
# Out:
# 13    11.0
# Name: Total_Spent, dtype: float64

# %% [raw]
# df.equals??

# %%
df.all()
# Out:
# Customer_ID           True
# Name                  True
# Age                   True
# Gender                True
# Country               True
# Date_of_Purchase      True
# Product_Category      True
# Product_ID            True
# Quantity              True
# Price_per_Unit        True
# Total_Spent           True
# Discount_Applied     False
# Payment_Method        True
# Customer_Feedback     True
# Membership_Status     True
# dtype: bool

# %%
df.any()
#df.any(axis='columns')
# Out:
# Customer_ID          True
# Name                 True
# Age                  True
# Gender               True
# Country              True
# Date_of_Purchase     True
# Product_Category     True
# Product_ID           True
# Quantity             True
# Price_per_Unit       True
# Total_Spent          True
# Discount_Applied     True
# Payment_Method       True
# Customer_Feedback    True
# Membership_Status    True
# dtype: bool

# %%
df['Total_Spent'].empty
#df.dropna().empty
# Out:
# False

# %% [raw]
# df.pop??

# %% [raw]
# df2.insert??

# %%
#df.update
new_column = pd.Series(['CHAL'], name='Name')
df2.update(new_column)
df2[:1]
# Out:
#    Customer_ID  Name  Age Gender Nation Date_of_Purchase Product_Category  \
# 0            1  CHAL   51   Male     UK       2022-09-09            Books
#
#    Product_ID  Quantity  Price_per_Unit  Total_Spent  Discount_Applied  \
# 0        1938         4           92.09       368.36             False
#
#   Payment_Method Customer_Feedback Membership_Status
# 0  Bank Transfer           Neutral               NaN

# %%
#df.append??

# %%
#df.join??

# %%
 df2.agg({'Total_Spent' : ['sum', 'min'], 'Quantity' : ['min', 'max']})
# Out:
#      Total_Spent  Quantity
# sum     23392.25       NaN
# min        11.00       1.0
# max          NaN       9.0

# %%
#df.transform?

# %%
df2['size'] = df2.groupby('Total_Spent')['Quantity'].transform('sum')
df2[:2]
# Out:
#    Customer_ID     Name  Age Gender  Nation Date_of_Purchase Product_Category  \
# 0            1     CHAL   51   Male      UK       2022-09-09            Books
# 1            2  Charlie   62   Male  Canada       2022-01-30            Books
#
#    Product_ID  Quantity  Price_per_Unit  Total_Spent  Discount_Applied  \
# 0        1938         4           92.09       368.36             False
# 1        1890         6           98.92       593.52              True
#
#   Payment_Method Customer_Feedback Membership_Status  size
# 0  Bank Transfer           Neutral               NaN     4
# 1         PayPal          Negative              Gold     6

# %%
df.melt(id_vars=['Total_Spent'], value_vars=['Quantity'])
# Out:
#     Total_Spent  variable  value
# 0        593.52  Quantity      6
# 1        282.33  Quantity      9
# 2        340.60  Quantity      5
# 3        892.35  Quantity      9
# 4        281.79  Quantity      3
# ..          ...       ...    ...
# 79       383.30  Quantity      5
# 80        65.90  Quantity      1
# 81       346.32  Quantity      9
# 82        31.58  Quantity      2
# 83       408.20  Quantity      5
#
# [84 rows x 3 columns]

# %% [raw]
# df.melt??

# %%
df2.stack(future_stack=True)
# Out:
# 0   Customer_ID                 1
#     Name                     CHAL
#     Age                        51
#     Gender                   Male
#     Nation                     UK
#                            ...
# 99  Discount_Applied        False
#     Payment_Method           Cash
#     Customer_Feedback    Negative
#     Membership_Status         NaN
#     size                        2
# Length: 1600, dtype: object

# %%
df2.unstack()
# Out:
# Customer_ID  0     1
#              1     2
#              2     3
#              3     4
#              4     5
#                   ..
# size         95    4
#              96    2
#              97    3
#              98    5
#              99    2
# Length: 1600, dtype: object

# %%
#df.explode() df.get()

# %%
#df.set_axis()??

# %%
df.plot()

# %%
df[['Name']][:5]
# Out:
#       Name
# 0  Charlie
# 1  Charlie
# 2    David
# 3      Eve
# 4      Eve

# %%
df[['Name', 'Age']][:5]
# Out:
#       Name  Age
# 0  Charlie   51
# 1  Charlie   62
# 2    David   42
# 3      Eve   67
# 4      Eve   65

# %%
df2.loc[0]
# Out:
# Customer_ID                      1
# Name                       Charlie
# Age                             51
# Gender                        Male
# Country                         UK
# Date_of_Purchase        2022-09-09
# Product_Category             Books
# Product_ID                    1938
# Quantity                         4
# Price_per_Unit               92.09
# Total_Spent                 368.36
# Discount_Applied             False
# Payment_Method       Bank Transfer
# Customer_Feedback          Neutral
# Membership_Status              NaN
# Name: 0, dtype: object

# %%
df['Product_Category'].value_counts()
# Out:
# Product_Category
# Books          13
# Electronics    12
# Clothing        9
# Furniture       8
# Groceries       8
# Name: count, dtype: int64

# %%
df2.loc[49, 'Product_Category']
# Out:
# 'Furniture'

# %%
df.loc[:, 'Payment_Method']
# Out:
# 0     Bank Transfer
# 1            PayPal
# 2       Credit Card
# 3              Cash
# 4              Cash
# 5       Credit Card
# 6     Bank Transfer
# 7            PayPal
# 8       Credit Card
# 9       Credit Card
# 10           PayPal
# 11           PayPal
# 12      Credit Card
# 13           PayPal
# 14      Credit Card
# 15    Bank Transfer
# 16           PayPal
# 17    Bank Transfer
# 18    Bank Transfer
# 19      Credit Card
# 20             Cash
# 21      Credit Card
# 22           PayPal
# 23             Cash
# 24             Cash
# 25           PayPal
# 26      Credit Card
# 27      Credit Card
# 28             Cash
# 29      Credit Card
# 30             Cash
# 31           PayPal
# 32             Cash
# 33           PayPal
# 34           PayPal
# 35      Credit Card
# 36             Cash
# 37      Credit Card
# 38      Credit Card
# 39           PayPal
# 40             Cash
# 41    Bank Transfer
# 42             Cash
# 43    Bank Transfer
# 44      Credit Card
# ...

# %%
df.loc[5:10]
# Out:
#     Customer_ID     Name  Age  Gender  Country Date_of_Purchase  \
# 5             6  Charlie   68  Female   France       2022-10-14
# 6             7    David   18    Male   France       2022-05-07
# 7             8    David   60    Male      USA       2022-10-02
# 8             9    Alice   25  Female  Germany       2022-01-03
# 9            10    David   24  Female   France       2022-08-13
# 10           11      Bob   46  Female       UK       2022-09-19
#
#    Product_Category  Product_ID  Quantity  Price_per_Unit  Total_Spent  \
# 5       Electronics        1345         3           93.93       281.79
# 6             Books        1802         1           53.74        53.74
# 7             Books        1931         2           19.65        39.30
# 8         Furniture        1208         4           60.46       241.84
# 9             Books        1046         7           58.08       406.56
# 10        Groceries        1186         9           58.90       530.10
#
# ...

# %%
df2.iloc[0]
# Out:
# Customer_ID                      1
# Name                       Charlie
# Age                             51
# Gender                        Male
# Country                         UK
# Date_of_Purchase        2022-09-09
# Product_Category             Books
# Product_ID                    1938
# Quantity                         4
# Price_per_Unit               92.09
# Total_Spent                 368.36
# Discount_Applied             False
# Payment_Method       Bank Transfer
# Customer_Feedback          Neutral
# Membership_Status              NaN
# Name: 0, dtype: object

# %%
df.iloc[:, 1].unique()
# Out:
# array(['Charlie', 'David', 'Eve', 'Alice', 'Bob'], dtype=object)

# %%
df.iloc[0:5, 0:2]
# Out:
#    Customer_ID     Name
# 0            1  Charlie
# 1            2  Charlie
# 2            3    David
# 3            4      Eve
# 4            5      Eve

# %%
df2.at[0, 'Payment_Method']
# Out:
# 'Bank Transfer'

# %%
df.iat[0, 1]
# Out:
# 'Charlie'

# %%
df['new_col'] =df['Quantity']*df['Price_per_Unit']
df['new_col'][:4]
# Out:
# 0    368.36
# 1    593.52
# 2    282.33
# 3    340.60
# Name: new_col, dtype: float64

# %%
df['Payment_Method'].unique()
# Out:
# array(['Bank Transfer', 'PayPal', 'Credit Card', 'Cash'], dtype=object)

# %%
df['Payment_Method'].nunique()
# Out:
# 4

# %%
'Payment_Method' in df.columns
# Out:
# True

# %%
df[df['Quantity'] > 8]
# Out:
#     Customer_ID     Name  Age  Gender  Country Date_of_Purchase  \
# 2             3    David   42    Male   Canada       2022-04-21
# 4             5      Eve   65  Female  Germany       2022-06-15
# 10           11      Bob   46  Female       UK       2022-09-19
# 33           34  Charlie   50  Female       UK       2022-10-21
# 41           42    David   61  Female   France       2022-03-21
# 48           49      Bob   46  Female   France       2022-03-13
#
#    Product_Category  Product_ID  Quantity  Price_per_Unit  Total_Spent  \
# 2             Books        1607         9           31.37       282.33
# 4          Clothing        1119         9           99.15       892.35
# 10        Groceries        1186         9           58.90       530.10
# 33      Electronics        1065         9           10.82        97.38
# 41      Electronics        1525         9           20.87       187.83
# 48      Electronics        1446         9            7.03        63.27
#
# ...

# %%
df[(df['Quantity'] > 5) & (df['Price_per_Unit'] < 39)]
# Out:
#     Customer_ID     Name  Age  Gender  Country Date_of_Purchase  \
# 2             3    David   42    Male   Canada       2022-04-21
# 21           22      Eve   38  Female       UK       2022-12-05
# 23           24      Bob   55  Female  Germany       2022-10-20
# 26           27    Alice   36    Male      USA       2022-04-01
# 27           28    Alice   60  Female       UK       2022-03-13
# 30           31    Alice   64  Female       UK       2022-01-14
# 32           33      Eve   36  Female       UK       2022-10-24
# 33           34  Charlie   50  Female       UK       2022-10-21
# 41           42    David   61  Female   France       2022-03-21
# 42           43      Bob   68    Male  Germany       2022-06-28
# 48           49      Bob   46  Female   France       2022-03-13
#
#    Product_Category  Product_ID  Quantity  Price_per_Unit  Total_Spent  \
# 2             Books        1607         9           31.37       282.33
# ...

# %%
df[(df['Discount_Applied'] == 'True') | (df['Customer_Feedback'] != 'Negative')]
# Out:
#     Customer_ID     Name  Age  Gender  Country Date_of_Purchase  \
# 0             1  Charlie   51    Male       UK       2022-09-09
# 2             3    David   42    Male   Canada       2022-04-21
# 3             4      Eve   67  Female       UK       2022-10-07
# 4             5      Eve   65  Female  Germany       2022-06-15
# 5             6  Charlie   68  Female   France       2022-10-14
# 7             8    David   60    Male      USA       2022-10-02
# 8             9    Alice   25  Female  Germany       2022-01-03
# 9            10    David   24  Female   France       2022-08-13
# 10           11      Bob   46  Female       UK       2022-09-19
# 12           13      Bob   69  Female       UK       2022-12-09
# 13           14    Alice   24  Female  Germany       2022-08-04
# 14           15      Bob   24  Female       UK       2022-03-02
# 15           16    David   47    Male   Canada       2022-05-25
# 16           17  Charlie   30    Male      USA       2022-08-07
# ...

# %%
#isin
df['Quantity'].isin([4, 7, 3]).value_counts()
# Out:
# Quantity
# False    33
# True     17
# Name: count, dtype: int64

# %%
df['Membership_Status'].str.contains('Gold').value_counts()
# Out:
# Membership_Status
# False    28
# True     14
# Name: count, dtype: int64

# %%
df['Membership_Status'].str.lower()
# Out:
# 0        NaN
# 1       gold
# 2     bronze
# 3     silver
# 4     bronze
# 5     bronze
# 6     bronze
# 7     bronze
# 8       gold
# 9     bronze
# 10    bronze
# 11      gold
# 12    bronze
# 13    bronze
# 14    silver
# 15      gold
# 16      gold
# 17      gold
# 18    bronze
# 19       NaN
# 20    silver
# 21       NaN
# 22       NaN
# 23    bronze
# 24    bronze
# 25      gold
# 26      gold
# 27    bronze
# 28    bronze
# 29    silver
# 30       NaN
# 31       NaN
# 32      gold
# 33    bronze
# 34    silver
# 35    bronze
# 36    bronze
# 37      gold
# 38      gold
# 39      gold
# 40       NaN
# 41    silver
# 42       NaN
# 43    bronze
# 44    silver
# 45      gold
# 46      gold
# 47    bronze
# 48    bronze
# 49    bronze
# Name: Membership_Status, dtype: object

# %%
df['Membership_Status'].str.upper()
# Out:
# 0        NaN
# 1       GOLD
# 2     BRONZE
# 3     SILVER
# 4     BRONZE
# 5     BRONZE
# 6     BRONZE
# 7     BRONZE
# 8       GOLD
# 9     BRONZE
# 10    BRONZE
# 11      GOLD
# 12    BRONZE
# 13    BRONZE
# 14    SILVER
# 15      GOLD
# 16      GOLD
# 17      GOLD
# 18    BRONZE
# 19       NaN
# 20    SILVER
# 21       NaN
# 22       NaN
# 23    BRONZE
# 24    BRONZE
# 25      GOLD
# 26      GOLD
# 27    BRONZE
# 28    BRONZE
# 29    SILVER
# 30       NaN
# 31       NaN
# 32      GOLD
# 33    BRONZE
# 34    SILVER
# 35    BRONZE
# 36    BRONZE
# 37      GOLD
# 38      GOLD
# 39      GOLD
# 40       NaN
# 41    SILVER
# 42       NaN
# 43    BRONZE
# 44    SILVER
# 45      GOLD
# 46      GOLD
# 47    BRONZE
# 48    BRONZE
# 49    BRONZE
# Name: Membership_Status, dtype: object

# %%
#help(df.str.strip)

# %%
df['Payment_Method'].str.replace('Credit Card', 'BANK_CARD')
# Out:
# 0     Bank Transfer
# 1            PayPal
# 2         BANK_CARD
# 3              Cash
# 4              Cash
# 5         BANK_CARD
# 6     Bank Transfer
# 7            PayPal
# 8         BANK_CARD
# 9         BANK_CARD
# 10           PayPal
# 11           PayPal
# 12        BANK_CARD
# 13           PayPal
# 14        BANK_CARD
# 15    Bank Transfer
# 16           PayPal
# 17    Bank Transfer
# 18    Bank Transfer
# 19        BANK_CARD
# 20             Cash
# 21        BANK_CARD
# 22           PayPal
# 23             Cash
# 24             Cash
# 25           PayPal
# 26        BANK_CARD
# 27        BANK_CARD
# 28             Cash
# 29        BANK_CARD
# 30             Cash
# 31           PayPal
# 32             Cash
# 33           PayPal
# 34           PayPal
# 35        BANK_CARD
# 36             Cash
# 37        BANK_CARD
# 38        BANK_CARD
# 39           PayPal
# 40             Cash
# 41    Bank Transfer
# 42             Cash
# 43    Bank Transfer
# 44        BANK_CARD
# ...

# %%
#df['col'].str.extract(r'regex')

# %%
df['Date_of_Purchase'] = pd.to_datetime(df['Date_of_Purchase'])
df['Date_of_Purchase'][:3]
# Out:
# 0   2022-09-09
# 1   2022-01-30
# 2   2022-04-21
# Name: Date_of_Purchase, dtype: datetime64[ns]

# %%
year=df['Date_of_Purchase'].dt.year
year[:3]
# Out:
# 0    2022
# 1    2022
# 2    2022
# Name: Date_of_Purchase, dtype: int32

# %%
month=df['Date_of_Purchase'].dt.month
month[:5]
# Out:
# 0     9
# 1     1
# 2     4
# 3    10
# 4     6
# Name: Date_of_Purchase, dtype: int32

# %%
day=df['Date_of_Purchase'].dt.day
day[:5]
# Out:
# 0     9
# 1    30
# 2    21
# 3     7
# 4    15
# Name: Date_of_Purchase, dtype: int32

# %%
weekday=df['Date_of_Purchase'].dt.weekday
weekday[:5]
# Out:
# 0    4
# 1    6
# 2    3
# 3    4
# 4    2
# Name: Date_of_Purchase, dtype: int32

# %%
hour=df['Date_of_Purchase'].dt.hour
hour[:2]
# Out:
# 0    0
# 1    0
# Name: Date_of_Purchase, dtype: int32

# %%
#df['Date_of_Purchase']= df['end'] - df['start']

# %%
#df['Date_of_Purchase'].dt.total_seconds()

# %%
df['new_col'].fillna(method='ffill')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12276\4280855375.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['new_col'].fillna(method='ffill')
# 0     368.36
# 1     593.52
# 2     282.33
# 3     340.60
# 4     892.35
# 5     281.79
# 6      53.74
# 7      39.30
# 8     241.84
# 9     406.56
# 10    530.10
# 11    232.25
# 12    526.12
# 13     11.00
# 14     51.54
# 15    278.19
# 16    160.84
# 17    303.03
# 18    698.39
# 19    264.80
# 20     93.04
# 21     74.48
# 22    215.22
# 23    114.60
# 24    486.35
# 25    557.52
# 26     43.20
# 27     47.82
# 28    156.15
# 29     49.40
# 30     77.77
# 31    163.89
# 32    172.74
# 33     97.38
# 34    144.84
# 35     45.29
# 36    196.15
# 37    371.30
# 38    197.04
# 39     83.30
# 40    270.00
# 41    187.83
# 42    102.48
# 43     31.35
# 44    171.96
# 45    115.68
# 46    219.78
# 47    405.65
# 48     63.27
# 49     82.72
# ...

# %%
df['new_col'].fillna(method='bfill')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12276\236894210.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['new_col'].fillna(method='bfill')
# 0     368.36
# 1     593.52
# 2     282.33
# 3     340.60
# 4     892.35
# 5     281.79
# 6      53.74
# 7      39.30
# 8     241.84
# 9     406.56
# 10    530.10
# 11    232.25
# 12    526.12
# 13     11.00
# 14     51.54
# 15    278.19
# 16    160.84
# 17    303.03
# 18    698.39
# 19    264.80
# 20     93.04
# 21     74.48
# 22    215.22
# 23    114.60
# 24    486.35
# 25    557.52
# 26     43.20
# 27     47.82
# 28    156.15
# 29     49.40
# 30     77.77
# 31    163.89
# 32    172.74
# 33     97.38
# 34    144.84
# 35     45.29
# 36    196.15
# 37    371.30
# 38    197.04
# 39     83.30
# 40    270.00
# 41    187.83
# 42    102.48
# 43     31.35
# 44    171.96
# 45    115.68
# 46    219.78
# 47    405.65
# 48     63.27
# 49     82.72
# ...

# %%
df.filter(like='Product_Category')
# Out:
#    Product_Category
# 0             Books
# 1             Books
# 2             Books
# 3       Electronics
# 4          Clothing
# 5       Electronics
# 6             Books
# 7             Books
# 8         Furniture
# 9             Books
# 10        Groceries
# 11            Books
# 12         Clothing
# 13      Electronics
# 14            Books
# 15        Furniture
# 16        Groceries
# 17            Books
# 18         Clothing
# 19      Electronics
# 20            Books
# 21         Clothing
# 22            Books
# 23        Groceries
# 24         Clothing
# 25        Furniture
# 26      Electronics
# 27            Books
# 28        Groceries
# 29        Groceries
# 30        Groceries
# 31        Furniture
# 32        Furniture
# 33      Electronics
# 34        Furniture
# 35      Electronics
# 36         Clothing
# 37      Electronics
# 38      Electronics
# 39            Books
# 40      Electronics
# 41      Electronics
# 42        Furniture
# 43         Clothing
# ...

# %%
df.filter(items=['Product_Category', 'Quantity'])
# Out:
#    Product_Category  Quantity
# 0             Books         4
# 1             Books         6
# 2             Books         9
# 3       Electronics         5
# 4          Clothing         9
# 5       Electronics         3
# 6             Books         1
# 7             Books         2
# 8         Furniture         4
# 9             Books         7
# 10        Groceries         9
# 11            Books         5
# 12         Clothing         7
# 13      Electronics         1
# 14            Books         2
# 15        Furniture         3
# 16        Groceries         4
# 17            Books         7
# 18         Clothing         7
# 19      Electronics         5
# 20            Books         2
# 21         Clothing         7
# 22            Books         3
# 23        Groceries         6
# 24         Clothing         5
# 25        Furniture         6
# 26      Electronics         8
# 27            Books         6
# 28        Groceries         5
# 29        Groceries         5
# ...

# %%
pd.options.display.max_rows=50
pd.options.display.max_columns = 50

# %%
pd.set_option('display.float_format', lambda x: f'{x:.2f}')

# %% [raw]
# df2.style.set_precision(1)

# %% [raw]
# df.style.background_gradient(axis=0)

# %%
df2['Quantity'].apply(lambda x: x**2)

# %%
df.apply(lambda row: row['a'] + row['b'], axis=1)

# %%
df.assign(newcol=lambda x: x['a'] + x['b'])

# %%
df.pipe?

# %%
df['col'].replace({1: 'A', 2: 'B'}),

# %%
df.groupby('Payment_Method').size()
# Out:
# Payment_Method
# Bank Transfer     7
# Cash             12
# Credit Card      18
# PayPal           13
# dtype: int64

# %%
df.groupby(['Payment_Method', 'Gender'])['Quantity'].sum()
# Out:
# Payment_Method  Gender
# Bank Transfer   Female     9
#                 Male      27
# Cash            Female    54
#                 Male      17
# Credit Card     Female    47
#                 Male      37
# PayPal          Female    33
#                 Male      22
# Name: Quantity, dtype: int64

# %%
df.groupby('Gender')['Quantity'].mean().reset_index()
# Out:
#    Gender  Quantity
# 0  Female      5.30
# 1    Male      4.48

# %%
df['Quantity'].groupby(level=0).sum()
# Out:
# 0     4
# 1     6
# 2     9
# 3     5
# 4     9
# 5     3
# 6     1
# 7     2
# 8     4
# 9     7
# 10    9
# 11    5
# 12    7
# 13    1
# 14    2
# 15    3
# 16    4
# 17    7
# 18    7
# 19    5
# 20    2
# 21    7
# 22    3
# 23    6
# 24    5
# 25    6
# 26    8
# 27    6
# 28    5
# 29    5
# 30    7
# 31    3
# 32    6
# 33    9
# 34    2
# 35    1
# 36    5
# 37    5
# 38    3
# 39    1
# 40    5
# 41    9
# 42    7
# 43    5
# 44    2
# 45    4
# 46    3
# 47    5
# 48    9
# 49    2
# Name: Quantity, dtype: int64

# %%
#df2.pivot(index='Name', columns='Discount_Applied', values='Quantity')

# %%
#df.pivot_table(index='a', columns='b', values='c', aggfunc='sum')

# %%
df3 = df2.explode('Customer_ID','Name')
df3[:3]
# Out:
#    Customer_ID     Name  Age Gender Country Date_of_Purchase Product_Category  \
# 0            1  Charlie   51   Male      UK       2022-09-09            Books
# 1            2  Charlie   62   Male  Canada       2022-01-30            Books
# 2            3    David   42   Male  Canada       2022-04-21            Books
#
#    Product_ID  Quantity  Price_per_Unit  Total_Spent  Discount_Applied  \
# 0        1938         4           92.09       368.36             False
# 1        1890         6           98.92       593.52              True
# 2        1607         9           31.37       282.33             False
#
#   Payment_Method Customer_Feedback Membership_Status
# 0  Bank Transfer           Neutral               NaN
# 1         PayPal          Negative              Gold
# 2    Credit Card          Positive            Bronze

# %%
i= df[df['Customer_ID'].notna()]
i[:9]
# Out:
#    Customer_ID     Name  Age  Gender  Country Date_of_Purchase  \
# 0            1  Charlie   51    Male       UK       2022-09-09
# 1            2  Charlie   62    Male   Canada       2022-01-30
# 2            3    David   42    Male   Canada       2022-04-21
# 3            4      Eve   67  Female       UK       2022-10-07
# 4            5      Eve   65  Female  Germany       2022-06-15
# 5            6  Charlie   68  Female   France       2022-10-14
# 6            7    David   18    Male   France       2022-05-07
# 7            8    David   60    Male      USA       2022-10-02
# 8            9    Alice   25  Female  Germany       2022-01-03
#
#   Product_Category  Product_ID  Quantity  Price_per_Unit  Total_Spent  \
# 0            Books        1938         4           92.09       368.36
# 1            Books        1890         6           98.92       593.52
# 2            Books        1607         9           31.37       282.33
# ...

# %%
o =df2[df2['Date_of_Purchase'] != '']
o[:3]
# Out:
#    Customer_ID     Name  Age Gender Country Date_of_Purchase Product_Category  \
# 0            1  Charlie   51   Male      UK       2022-09-09            Books
# 1            2  Charlie   62   Male  Canada       2022-01-30            Books
# 2            3    David   42   Male  Canada       2022-04-21            Books
#
#    Product_ID  Quantity  Price_per_Unit  Total_Spent  Discount_Applied  \
# 0        1938         4           92.09       368.36             False
# 1        1890         6           98.92       593.52              True
# 2        1607         9           31.37       282.33             False
#
#   Payment_Method Customer_Feedback Membership_Status
# 0  Bank Transfer           Neutral               NaN
# 1         PayPal          Negative              Gold
# 2    Credit Card          Positive            Bronze

# %%
df['Age'] = df['Age'].astype(int)

# %%
df2['Country'] = df2['Country'].astype(str)

# %%
df3= pd.concat([df, df2], axis=0)
df3.shape
# Out:
# (100, 16)

# %%
#df4 = pd.concat([df, df3], axis=1)

# %%
merged = pd.merge(df, df2, on='id')
merged
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12276\3990919489.py in ?()
# ----> 1 merged = pd.merge(df, df2, on='id')
#       2 merged.shape
#
# ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
# ...

# %%
df3= df3.drop(columns=['Country','size'])
df3[:5]
# Out:
# KeyboardInterrupt

# %%
s= df2.drop(index=[0, 1, 2])
s

# %%
d= df[df.index != 5]
d

# %%
df.columns = df.columns.str.strip()

# %%
df.columns = df.columns.str.replace(' ', '_')
